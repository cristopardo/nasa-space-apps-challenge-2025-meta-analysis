# %% [markdown]
# # NASA Space Apps Repo Meta-Analysis
#
# This notebook loads a CSV of repositories, analyzes Git metadata via modular helpers (spaceapps_meta), and produces a pandas DataFrame and charts.

# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

df = pd.read_csv("data/repo_metadata.tsv", sep="\t")

# %%
df.head(20)
# Out:
#                                             repo_slug default_branch  \
# 0                    ChangeMakerGroupEdition_Sunshine           main
# 1                           dengrenhao_3D_ISS_Tracker           main
# 2                          GaelleMG_starflock_firexaq           main
# 3                      HSSBoston_earth-wind-and-flare           main
# 4                          HSSBoston_jimmy-in-the-box           main
# 5                           Laurence-Cullen_Asteroids           main
# 6                           LLuisPP_NASA_MoonquakeApp           main
# 7                         lucianosantiviago_MIMBI_eng           main
# 8                 OceanGardens_oceangardens.github.io           main
# 9                    rociopey_landslidedetectionsquad           main
# 10  samirimtiaz1996_NASAInternationalSpaceAppsChal...           main
# 11                    s-antoniou_nsac-space-travelers           main
# 12                                 TsungTang_debugger           main
#
# ...
